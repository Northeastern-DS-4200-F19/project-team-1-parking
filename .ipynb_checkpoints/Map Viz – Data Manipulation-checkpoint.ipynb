# %%
import pandas as pd
import numpy as np

import matplotlib
from matplotlib import pyplot as plt
import plotly.express as px

# %%
intersection_df = pd.read_excel(
    io='./data/Parking survey data.xlsx', 
    sheet_name='Intersection Table for Pandas',
)

# %%
intersection_df
# Out:
#     Intersection ID             Section A              Section B  x coord  \
# 0                 1  Massachusetts Avenue         Shawmut Avenue   0.5000
# 1                 2  Massachusetts Avenue   Chester Square - 2.1   0.5000
# 2                 3  Massachusetts Avenue   Chester Square - 2.3   0.5000
# 3                 4  Massachusetts Avenue   Chester Square - 9.1   0.5000
# 4                 5  Massachusetts Avenue   Chester Square - 9.3   0.5000
# 5                 6  Massachusetts Avenue         Tremont Street   0.5000
# 6                 7        Tremont Street     Northampton Street   0.0000
# 7                 8        Tremont Street  W. Springfield Street   1.0000
# 8                 9        Shawmut Avenue     Northampton Street   0.0000
# 9                10        Shawmut Avenue  W. Springfield Street   1.0000
# 10               11  Chester Square - 2.1   Chester Square - 2.2   0.6875
# 11               12  Chester Square - 2.2   Chester Square - 2.3   0.6875
# 12               13  Chester Square - 9.1   Chester Square - 9.2   0.3125
# 13               14  Chester Square - 9.2   Chester Square - 9.3   0.3125
#
#     y coord
# 0      2.00
# 1      1.50
# 2      0.50
# 3      0.50
# 4      1.50
# 5      0.00
# 6      0.00
# 7      0.00
# 8      2.00
# 9      2.00
# 10     1.25
# 11     0.75
# 12     0.75
# 13     1.25

# %%
segment_df = pd.read_excel(
    io='./data/Parking survey data.xlsx', 
    sheet_name='Segment Table for Pandas',
    index_col='Segment ID'
)

# %%
segment_df
# Out:
#             Segment Number Street Side Route Number            Street Name  \
# Segment ID
# 1R                     1.0           R            1   Massachusetts Avenue
# 2.1R                   2.1           R            2   Chester Square - 2.1
# 2.1L                   2.1           L            2   Chester Square - 2.1
# 2.2L                   2.2           L            2   Chester Square - 2.2
# 2.2R                   2.2           R            2   Chester Square - 2.2
# 2.3R                   2.3           R            2   Chester Square - 2.3
# 2.3L                   2.3           L            2   Chester Square - 2.3
# 3.1R                   3.1           R           3a   Massachusetts Avenue
# 3.2R                   3.2           R           3b   Massachusetts Avenue
# 4R                     4.0           R            4         Tremont Street
# 5R                     5.0           R            5         Tremont Street
# 6R                     6.0           R            6         Tremont Street
# 7R                     7.0           R            7         Tremont Street
# 8R                     8.0           R            8   Massachusetts Avenue
# 9.1R                   9.1           R            9   Chester Square - 9.1
# 9.1L                   9.1           L            9   Chester Square - 9.1
# 9.2R                   9.2           R            9   Chester Square - 9.2
# 9.2L                   9.2           L            9   Chester Square - 9.2
# 9.3R                   9.3           R            9   Chester Square - 9.3
# 9.3L                   9.3           L            9   Chester Square - 9.3
# 10.1R                 10.1           R          10a   Massachusetts Avenue
# 10.2R                 10.2           R          10b   Massachusetts Avenue
# 11L                   11.0           L           11         Shawmut Avenue
# 11R                   11.0           R           11         Shawmut Avenue
# 12L                   12.0           L           12     Northampton Street
# 12R                   12.0           R           12     Northampton Street
# 13R                   13.0           R           13  W. Springfield Street
# 13L                   13.0           L           13  W. Springfield Street
# 14R                   14.0           R           14         Shawmut Avenue
# 14L                   14.0           L           14         Shawmut Avenue
#
#            Street Direction     Start Bound Street       End Bound Street  \
# Segment ID
# 1R                    North         Shawmut Avenue   Chester Square - 2.1
# 2.1R                  North   Massachusetts Avenue   Chester Square - 2.2
# 2.1L                  North   Massachusetts Avenue   Chester Square - 2.2
# 2.2L                  North   Chester Square - 2.1   Chester Square - 2.3
# 2.2R                  North   Chester Square - 2.1   Chester Square - 2.3
# 2.3R                  North   Chester Square - 2.2   Massachusetts Avenue
# 2.3L                  North   Chester Square - 2.2   Massachusetts Avenue
# 3.1R                  North   Chester Square - 2.1   Chester Square - 2.3
# 3.2R                  North   Chester Square - 2.3         Tremont Street
# 4R                     West   Massachusetts Avenue  W. Springfield Street
# 5R                     East  W. Springfield Street   Massachusetts Avenue
# 6R                     East   Massachusetts Avenue     Northampton Street
# 7R                     West     Northampton Street   Massachusetts Avenue
# 8R                    South         Tremont Street   Chester Square - 9.1
# 9.1R                  South   Massachusetts Avenue   Chester Square - 9.2
# 9.1L                  South   Massachusetts Avenue   Chester Square - 9.2
# 9.2R                  South   Chester Square - 9.1   Chester Square - 9.3
# 9.2L                  South   Chester Square - 9.1   Chester Square - 9.3
# 9.3R                  South   Chester Square - 9.2   Massachusetts Avenue
# 9.3L                  South   Chester Square - 9.2   Massachusetts Avenue
# 10.1R                 South   Chester Square - 9.1   Chester Square - 9.3
# 10.2R                 South   Chester Square - 9.3         Shawmut Avenue
# 11L                    West   Massachusetts Avenue     Northampton Street
# 11R                    West   Massachusetts Avenue     Northampton Street
# 12L                   North         Shawmut Avenue         Tremont Street
# 12R                   North         Shawmut Avenue         Tremont Street
# 13R                   South         Tremont Street         Shawmut Avenue
# 13L                   South         Tremont Street         Shawmut Avenue
# 14R                    West  W. Springfield Street   Massachusetts Avenue
# 14L                    West  W. Springfield Street   Massachusetts Avenue
#
#                 x1    y1      x2    y2
# Segment ID
# 1R          0.5000  2.00  0.5000  1.00
# 2.1R        0.5000  1.50  0.6875  1.25
# 2.1L        0.5000  1.50  0.6875  1.25
# 2.2L        0.6875  1.25  0.6875  0.75
# 2.2R        0.6875  1.25  0.6875  0.75
# 2.3R        0.6875  0.75  0.5000  0.50
# 2.3L        0.6875  0.75  0.5000  0.50
# 3.1R        0.5000  1.50  0.5000  0.50
# 3.2R        0.5000  0.50  0.5000  2.00
# 4R          0.5000  0.00  1.0000  0.00
# 5R          1.0000  0.00  0.5000  0.00
# 6R          0.5000  0.00  0.0000  0.00
# 7R          0.0000  0.00  0.5000  0.00
# 8R          0.5000  0.00  0.5000  0.50
# 9.1R        0.5000  0.50  0.3125  0.75
# 9.1L        0.5000  0.50  0.3125  0.75
# 9.2R        0.3125  0.75  0.3125  1.25
# 9.2L        0.3125  0.75  0.3125  1.25
# 9.3R        0.3125  1.25  0.5000  1.50
# 9.3L        0.3125  1.25  0.5000  1.50
# 10.1R       0.5000  0.50  0.5000  1.50
# 10.2R       0.5000  1.50  0.5000  2.00
# 11L         0.5000  2.00  0.0000  2.00
# 11R         0.5000  2.00  0.0000  2.00
# 12L         0.0000  2.00  0.0000  0.00
# 12R         0.0000  2.00  0.0000  0.00
# 13R         1.0000  0.00  1.0000  2.00
# 13L         1.0000  0.00  1.0000  2.00
# 14R         1.0000  2.00  0.5000  2.00
# 14L         1.0000  2.00  0.5000  2.00

# %%
intersection_df.to_csv('./data/intersections_data.csv', index_label='id')
segment_df.to_csv('./data/segments_data.csv')
