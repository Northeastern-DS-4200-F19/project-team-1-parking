# %%
import pandas as pd
import numpy as np

import matplotlib
from matplotlib import pyplot as plt
import plotly.express as px

# %%
intersection_df = pd.read_excel(
    io='./data/Parking survey data.xlsx', 
    sheet_name='Intersection Table for Pandas',
    index_col='id'
)

# %%
intersection_df
# Out:
#                Section A              Section B       x     y
# id
# 1   Massachusetts Avenue         Shawmut Avenue  0.5000  2.00
# 2   Massachusetts Avenue   Chester Square - 2.1  0.5000  1.50
# 3   Massachusetts Avenue   Chester Square - 2.3  0.5000  0.50
# 4   Massachusetts Avenue   Chester Square - 9.1  0.5000  0.50
# 5   Massachusetts Avenue   Chester Square - 9.3  0.5000  1.50
# 6   Massachusetts Avenue         Tremont Street  0.5000  0.00
# 7         Tremont Street     Northampton Street  0.0000  0.00
# 8         Tremont Street  W. Springfield Street  1.0000  0.00
# 9         Shawmut Avenue     Northampton Street  0.0000  2.00
# 10        Shawmut Avenue  W. Springfield Street  1.0000  2.00
# 11  Chester Square - 2.1   Chester Square - 2.2  0.6875  1.25
# 12  Chester Square - 2.2   Chester Square - 2.3  0.6875  0.75
# 13  Chester Square - 9.1   Chester Square - 9.2  0.3125  0.75
# 14  Chester Square - 9.2   Chester Square - 9.3  0.3125  1.25

# %%
segment_df = pd.read_excel(
    io='./data/Parking survey data.xlsx', 
    sheet_name='Segment Table for Pandas',
    index_col='id'
)

# %%
segment_df
# Out:
#        Segment Number Street Side Route Number            Street Name  \
# id
# 1R                1.0           R            1   Massachusetts Avenue
# 2.1R              2.1           R            2   Chester Square - 2.1
# 2.1L              2.1           L            2   Chester Square - 2.1
# 2.2L              2.2           L            2   Chester Square - 2.2
# 2.2R              2.2           R            2   Chester Square - 2.2
# 2.3R              2.3           R            2   Chester Square - 2.3
# 2.3L              2.3           L            2   Chester Square - 2.3
# 3.1R              3.1           R           3a   Massachusetts Avenue
# 3.2R              3.2           R           3b   Massachusetts Avenue
# 4R                4.0           R            4         Tremont Street
# 5R                5.0           R            5         Tremont Street
# 6R                6.0           R            6         Tremont Street
# ...

# %%
intersection_df.to_csv('./data/intersections_data.csv')
segment_df.to_csv('./data/segments_data.csv')
